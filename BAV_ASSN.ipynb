# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\python312\lib\site-packages\vboxapi-1.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
cipla = yf.Ticker("CIPLA.NS")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#       5 import warnings
#       6 warnings.filterwarnings('ignore')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
balance_sheet = cipla.balance_sheet
balance_sheet=balance_sheet.T
balance_sheet = balance_sheet.sort_index(ascending=True)
balance_sheet
# Out:
#            Treasury Shares Number Ordinary Shares Number Share Issued  \
# 2020-03-31                    NaN                    NaN          NaN
# 2021-03-31                    NaN            806463279.0  806463279.0
# 2022-03-31                    NaN            806814036.0  806814036.0
# 2023-03-31                    NaN            807150593.0  807150593.0
# 2024-03-31                    0.0            807367062.0  807367062.0
#
#                  Net Debt     Total Debt Tangible Book Value Invested Capital  \
# 2020-03-31  20740500000.0            NaN                 NaN              NaN
# 2021-03-31   9622700000.0  20144100000.0      134909800000.0   200820900000.0
# 2022-03-31   1464000000.0  10557800000.0      160009000000.0   216658300000.0
# 2023-03-31            NaN   8031200000.0      188937800000.0   239281400000.0
# 2024-03-31            NaN   5594100000.0      219933900000.0   269534500000.0
#
# ...

# %%
income_statement = cipla.financials
income_statement=income_statement.T
income_statement=income_statement.sort_index(ascending=True)
income_statement
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2021-03-31                 183911090.0             0.2701     43780700000.0
# 2022-03-31                -336584160.0             0.2673     47141200000.0
# 2023-03-31                -432074160.0             0.2979     51147200000.0
# 2024-03-31                  57440160.0             0.2712     66934600000.0
#
#            Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 2021-03-31         680900000.0                            680900000.0
# 2022-03-31       -1259200000.0                          -1259200000.0
# 2023-03-31         373800000.0                          -1450400000.0
# 2024-03-31         211800000.0                            211800000.0
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2021-03-31                                      24048700000.0
# 2022-03-31                                      25167500000.0
# ...

# %%
income_statement.columns
# Out:
# Index(['Tax Effect Of Unusual Items', 'Tax Rate For Calcs',
#        'Normalized EBITDA', 'Total Unusual Items',
#        'Total Unusual Items Excluding Goodwill',
#        'Net Income From Continuing Operation Net Minority Interest',
#        'Reconciled Depreciation', 'Reconciled Cost Of Revenue', 'EBITDA',
#        'EBIT', 'Net Interest Income', 'Interest Expense', 'Interest Income',
#        'Normalized Income',
#        'Net Income From Continuing And Discontinued Operation',
#        'Total Expenses', 'Rent Expense Supplemental', 'Diluted Average Shares',
#        'Basic Average Shares', 'Diluted EPS', 'Basic EPS',
#        'Diluted NI Availto Com Stockholders', 'Net Income Common Stockholders',
#        'Otherunder Preferred Stock Dividend', 'Net Income',
#        'Minority Interests', 'Net Income Including Noncontrolling Interests',
#        'Net Income Continuous Operations', 'Tax Provision', 'Pretax Income',
# ...

# %%
income_statement['Total Revenue']
# Out:
# 2021-03-31    189885200000.0
# 2022-03-31    216233600000.0
# 2023-03-31    224731800000.0
# 2024-03-31    254466300000.0
# Name: Total Revenue, dtype: object

# %%
income_statement['Total Revenue'].pct_change().mean()
# Out:
# 0.10345723093450239

# %%
balance_sheet_common_size = balance_sheet.div(balance_sheet['Total Assets'], axis=0) * 100
balance_sheet_common_size
# Out:
#            Treasury Shares Number Ordinary Shares Number Share Issued  \
# 2020-03-31                    NaN                    NaN          NaN
# 2021-03-31                    NaN               0.320637     0.320637
# 2022-03-31                    NaN               0.297705     0.297705
# 2023-03-31                    NaN               0.273951     0.273951
# 2024-03-31                    0.0               0.246767     0.246767
#
#             Net Debt Total Debt Tangible Book Value Invested Capital  \
# 2020-03-31       NaN        NaN                 NaN              NaN
# 2021-03-31  3.825836   8.008981           53.638037        79.843264
# 2022-03-31  0.540199   3.895706           59.041471        79.944408
# 2023-03-31       NaN   2.725834           64.126533        81.213429
# 2024-03-31       NaN   1.709802           67.221441        82.381558
#
#            Working Capital Net Tangible Assets Capital Lease Obligations  ...  \
# ...

# %%
balance_sheet_common_size.columns
# Out:
# Index(['Treasury Shares Number', 'Ordinary Shares Number', 'Share Issued',
#        'Net Debt', 'Total Debt', 'Tangible Book Value', 'Invested Capital',
#        'Working Capital', 'Net Tangible Assets', 'Capital Lease Obligations',
#        'Common Stock Equity', 'Total Capitalization',
#        'Total Equity Gross Minority Interest', 'Minority Interest',
#        'Stockholders Equity', 'Other Equity Interest', 'Retained Earnings',
#        'Additional Paid In Capital', 'Capital Stock', 'Common Stock',
#        'Total Liabilities Net Minority Interest',
#        'Total Non Current Liabilities Net Minority Interest',
#        'Other Non Current Liabilities', 'Derivative Product Liabilities',
#        'Non Current Pension And Other Postretirement Benefit Plans',
#        'Non Current Deferred Revenue',
#        'Non Current Deferred Taxes Liabilities',
#        'Long Term Debt And Capital Lease Obligation',
#        'Long Term Capital Lease Obligation', 'Long Term Debt',
# ...

# %%
income_statement_common_size = income_statement.div(income_statement['Total Revenue'], axis=0) * 100
income_statement_common_size
# Out:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 2021-03-31                    0.096854                0.0         23.056405
# 2022-03-31                   -0.155658                0.0         21.801052
# 2023-03-31                   -0.192262                0.0         22.759218
# 2024-03-31                    0.022573                0.0         26.303915
#
#            Total Unusual Items Total Unusual Items Excluding Goodwill  \
# 2021-03-31            0.358585                               0.358585
# 2022-03-31           -0.582333                              -0.582333
# 2023-03-31            0.166332                              -0.645392
# 2024-03-31            0.083233                               0.083233
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2021-03-31                                          12.664863
# 2022-03-31                                          11.639033
# ...

# %%
current_ratio = balance_sheet['Current Assets'] / balance_sheet['Current Liabilities']*100
quick_ratio = (balance_sheet['Current Assets'] - balance_sheet['Inventory']) / balance_sheet['Current Liabilities']*100
liabilities_to_assets=balance_sheet['Current Liabilities'] / balance_sheet['Current Assets']*100
debt_equity_ratio= balance_sheet['Net Debt']/balance_sheet['Stockholders Equity']*100
gross_margin = (income_statement['Gross Profit'] / income_statement['Total Revenue']) *100
operating_margin = (income_statement['Operating Income'] / income_statement['Total Revenue'])* 100
net_margin = (income_statement['Net Income'] / income_statement['Total Revenue']) *100

# %%
import matplotlib.pyplot as plt

# Calculate the ratios
current_ratio = balance_sheet['Current Assets'] / balance_sheet['Current Liabilities'] * 100
quick_ratio = (balance_sheet['Current Assets'] - balance_sheet['Inventory']) / balance_sheet['Current Liabilities'] * 100
liabilities_to_assets = balance_sheet['Current Liabilities'] / balance_sheet['Current Assets'] * 100
gross_margin = (income_statement['Gross Profit'] / income_statement['Total Revenue']) * 100
operating_margin = (income_statement['Operating Income'] / income_statement['Total Revenue']) * 100
net_margin = (income_statement['Net Income'] / income_statement['Total Revenue']) * 100
years=['2021-03-31','2022-03-31','2023-03-31','2024-03-31']

# Create subplots
fig, axs = plt.subplots(3, 2, figsize=(14, 16))
fig.tight_layout(pad=5.0)

axs[0, 0].plot(years, current_ratio.dropna().to_numpy(), marker='o')
axs[0, 0].set_title('Current Ratio (%)')
axs[0, 0].set_xlabel('Year')
axs[0, 0].set_ylabel('Current Ratio')

axs[0, 1].plot(years, quick_ratio.dropna().to_numpy(), marker='o')
axs[0, 1].set_title('Quick Ratio (%)')
axs[0, 1].set_xlabel('Year')
axs[0, 1].set_ylabel('Quick Ratio')

axs[1, 0].plot(years, liabilities_to_assets.dropna().to_numpy(), marker='o')
axs[1, 0].set_title('Liabilities to Assets (%)')
axs[1, 0].set_xlabel('Year')
axs[1, 0].set_ylabel('Liabilities to Assets')

# axs[1, 1].plot(years, debt_equity_ratio.dropna().to_numpy(), marker='o')
# axs[1, 1].set_title('Debt to Equity Ratio (%)')
# axs[1, 1].set_xlabel('Year')
# axs[1, 1].set_ylabel('Debt to Equity Ratio')

axs[2, 0].plot(years, gross_margin.dropna().to_numpy(), marker='o')
axs[2, 0].set_title('Gross Margin (%)')
axs[2, 0].set_xlabel('Year')
axs[2, 0].set_ylabel('Gross Margin')

axs[2, 1].plot(years, operating_margin.dropna().to_numpy(), marker='o')
axs[2, 1].set_title('Operating Margin (%)')
axs[2, 1].set_xlabel('Year')
axs[2, 1].set_ylabel('Operating Margin')

axs[1, 1].plot(years, net_margin.dropna().to_numpy(), marker='o')
axs[1, 1].set_title('Net Margin (%)')
axs[1, 1].set_xlabel('Year')
axs[1, 1].set_ylabel('Net Margin')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # Calculate the ratios
#       4 current_ratio = balance_sheet['Current Assets'] / balance_sheet['Current Liabilities'] * 100
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt

# Calculate additional ratios
cash_ratio = (balance_sheet['Cash And Cash Equivalents'] / balance_sheet['Current Liabilities']) * 100
working_capital_ratio = ((balance_sheet['Current Assets'] - balance_sheet['Current Liabilities']) / balance_sheet['Current Liabilities']) * 100
return_on_assets = (income_statement['Net Income'] / balance_sheet['Total Assets']) * 100
return_on_equity = (income_statement['Net Income'] / balance_sheet['Stockholders Equity']) * 100

fig, axs = plt.subplots(2, 2, figsize=(12, 10))
fig.tight_layout(pad=5.0)

# Plot each new ratio
axs[0, 0].plot(years, cash_ratio.dropna().to_numpy(), marker='o')
axs[0, 0].set_title('Cash Ratio (%)')
axs[0, 0].set_xlabel('Year')
axs[0, 0].set_ylabel('Cash Ratio')

axs[0, 1].plot(years, working_capital_ratio.dropna().to_numpy(), marker='o')
axs[0, 1].set_title('Working Capital Ratio (%)')
axs[0, 1].set_xlabel('Year')
axs[0, 1].set_ylabel('Working Capital Ratio')

axs[1, 0].plot(years, return_on_assets.dropna().to_numpy(), marker='o')
axs[1, 0].set_title('Return on Assets (ROA) (%)')
axs[1, 0].set_xlabel('Year')
axs[1, 0].set_ylabel('Return on Assets')

axs[1, 1].plot(years, return_on_equity.dropna().to_numpy(), marker='o')
axs[1, 1].set_title('Return on Equity (ROE) (%)')
axs[1, 1].set_xlabel('Year')
axs[1, 1].set_ylabel('Return on Equity')

plt.show()

# %%
cash_ratio
# Out:
# 2020-03-31          NaN
# 2021-03-31    17.277172
# 2022-03-31     13.79424
# 2023-03-31    12.283181
# 2024-03-31    12.201641
# dtype: object

# %%
debt_equity_ratio
# Out:
# 2020-03-31         NaN
# 2021-03-31    5.250694
# 2022-03-31    0.702438
# 2023-03-31         NaN
# 2024-03-31         NaN
# dtype: object

# %%
income_statement['Tax Rate For Calcs']
# Out:
# 2021-03-31    0.2701
# 2022-03-31    0.2673
# 2023-03-31    0.2979
# 2024-03-31    0.2712
# Name: Tax Rate For Calcs, dtype: object

# %%
ebit = income_statement['EBIT']
depreciation = balance_sheet['Accumulated Depreciation'].diff()
capex = balance_sheet['Gross PPE'].diff()
wc_delta=balance_sheet['Working Capital'].diff()
net_borrowing = balance_sheet['Long Term Debt And Capital Lease Obligation'].diff()
interest_expense = income_statement['Interest Expense']
tax_rate = income_statement['Tax Rate For Calcs']
fcfe = ebit*(1-tax_rate) + depreciation - capex -wc_delta + net_borrowing - interest_expense*(1-tax_rate)
print(fcfe)
fcff = ebit*(1-tax_rate) + depreciation - capex - wc_delta
print(fcff)
# Out:
# 2020-03-31                  NaN
# 2021-03-31                  NaN
# 2022-03-31        -7064210710.0
# 2023-03-31   -8577344650.000004
# 2024-03-31        13150547200.0
# dtype: object
# 2020-03-31                  NaN
# 2021-03-31                  NaN
# 2022-03-31         1965225240.0
# 2023-03-31   -4256438890.000004
# 2024-03-31        13502942640.0
# dtype: object

# %%
import matplotlib.pyplot as plt

valid_years=years[1:]
fig, axs = plt.subplots(3, 2, figsize=(12, 15))
fig.tight_layout(pad=5.0)

# Plot each component on a separate subplot
axs[0, 0].plot(valid_years, depreciation.dropna().to_numpy(), marker='o')
axs[0, 0].set_title('Depreciation')
axs[0, 0].set_xlabel('Year')
axs[0, 0].set_ylabel('Depreciation')

axs[0, 1].plot(valid_years, capex.dropna().to_numpy(), marker='o')
axs[0, 1].set_title('Capital Expenditure (CapEx)')
axs[0, 1].set_xlabel('Year')
axs[0, 1].set_ylabel('CapEx')

axs[1, 0].plot(valid_years, wc_delta.dropna().to_numpy(), marker='o')
axs[1, 0].set_title('Working Capital Change (ΔWC)')
axs[1, 0].set_xlabel('Year')
axs[1, 0].set_ylabel('ΔWC')

axs[1, 1].plot(valid_years, net_borrowing.dropna().to_numpy(), marker='o')
axs[1, 1].set_title('Net Borrowing')
axs[1, 1].set_xlabel('Year')
axs[1, 1].set_ylabel('Net Borrowing')

axs[2, 0].plot(years, ebit.to_numpy(), marker='o')
axs[2, 0].set_title('EBIT')
axs[2, 0].set_xlabel('Year')
axs[2, 0].set_ylabel('EBIT')

axs[2, 1].plot(years, interest_expense.to_numpy(), marker='o')
axs[2, 1].set_title('Interest Expense')
axs[2, 1].set_xlabel('Year')
axs[2, 1].set_ylabel('Interest Expense')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
tax_rate=0.27
ebit_pct_change = ebit.pct_change().mean()
depreciation_pct_change = depreciation.pct_change().mean()
capex_pct_change = capex.pct_change().mean()
wc_delta_pct_change = wc_delta.pct_change().mean()
net_borrowing_pct_change = net_borrowing.pct_change().mean()
interest_expense_pct_change=interest_expense.pct_change().mean()
fcfe_forecast=pd.DataFrame(columns=['Year','EBIT','Depreciation','Capex','Change in Working Capital','Interest Expense','Change in Net Borrowing','FCFF','FCFE'])

for year in ['2022-03-31','2023-03-31','2024-03-31']:
    row1=[year,ebit[year],depreciation[year], capex[year], wc_delta[year],interest_expense[year],net_borrowing[year], fcff[year], fcfe[year]]
    fcfe_forecast.loc[len(fcfe_forecast)] = row1

last_date='2024-03-31'
for i in range(1, 11):
    year = str(int(last_date[:4]) + i) + last_date[4:]
    prev_index = len(fcfe_forecast) - 1  # Index of the last row
    
    forecast_ebit = fcfe_forecast.loc[prev_index, 'EBIT'] * (1 + ebit_pct_change)
    forecast_depreciation = fcfe_forecast.loc[prev_index, 'Depreciation'] * (1 + depreciation_pct_change)
    forecast_capex = fcfe_forecast.loc[prev_index, 'Capex'] * (1 + capex_pct_change)
    forecast_wc_delta = fcfe_forecast.loc[prev_index, 'Change in Working Capital'] * (1 + wc_delta_pct_change)
    forecast_net_borrowing = fcfe_forecast.loc[prev_index, 'Change in Net Borrowing'] * (1 + net_borrowing_pct_change)
    forecast_interest_expense = fcfe_forecast.loc[prev_index, 'Interest Expense'] * (1 + interest_expense_pct_change)
    
    forecast_fcff = forecast_ebit * (1 - tax_rate) + forecast_depreciation - forecast_capex - forecast_wc_delta
    forecast_fcfe = forecast_fcff + forecast_net_borrowing - forecast_interest_expense * (1 - tax_rate)
    fcfe_forecast.loc[len(fcfe_forecast)] = [
        year,
        forecast_ebit,
        forecast_depreciation,
        forecast_capex,
        forecast_wc_delta,
        forecast_interest_expense,
        forecast_net_borrowing,
        forecast_fcff,
        forecast_fcfe
    ]
fcfe_forecast
# Out:
#           Year          EBIT  Depreciation         Capex  \
# 0   2022-03-31  3.598120e+10 -5.931300e+09  6.503200e+09
# 1   2023-03-31  4.132910e+10 -3.976300e+09  5.787800e+09
# 2   2024-03-31  5.773030e+10 -2.691200e+09  5.576100e+09
# 3   2025-03-31  6.909385e+10 -1.812796e+09  5.167416e+09
# 4   2026-03-31  8.269419e+10 -1.221102e+09  4.788685e+09
# 5   2027-03-31  9.897160e+10 -8.225359e+08  4.437712e+09
# 6   2028-03-31  1.184530e+11 -5.540613e+08  4.112462e+09
# 7   2029-03-31  1.417692e+11 -3.732165e+08  3.811051e+09
# 8   2030-03-31  1.696748e+11 -2.513991e+08  3.531731e+09
# 9   2031-03-31  2.030734e+11 -1.693428e+08  3.272883e+09
# 10  2032-03-31  2.430461e+11 -1.140695e+08  3.033006e+09
# 11  2033-03-31  2.908869e+11 -7.683741e+07  2.810710e+09
# 12  2034-03-31  3.481447e+11 -5.175778e+07  2.604707e+09
#
#     Change in Working Capital  Interest Expense  Change in Net Borrowing  \
# 0                1.196370e+10      1.048500e+09            -8.261200e+09
# ...

# %%
final_fcfe=fcfe_forecast['FCFE'].to_numpy()
final_fcff=fcfe_forecast['FCFF'].to_numpy()
import matplotlib.pyplot as plt
years=[i for i in range(2022,2035)]
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
fig.tight_layout(pad=5.0)

axs[0].plot(years, final_fcfe, marker='o', color='b')
axs[0].set_title('Final FCFE')
axs[0].set_xlabel('Year')
axs[0].set_ylabel('FCFE')

axs[1].plot(years, final_fcff, marker='o', color='g')
axs[1].set_title('Final FCFF')
axs[1].set_xlabel('Year')
axs[1].set_ylabel('FCFF')

plt.show()

# %% [markdown]
# **1.2 STARTS HERE**

# %%
import statsmodels.api as sm
ticker = "CIPLA.NS" 
market_index = "^NSEI" 

start_date = '2019-03-31'
end_date = '2024-03-31'
cipla_data= yf.download(ticker, start=start_date, end= end_date)
market_data= yf.download(market_index, start=start_date,end= end_date)
cipla_returns = cipla_data['Adj Close'].pct_change().dropna()
market_returns = market_data['Adj Close'].pct_change().dropna()

#aligning data by date
returns = pd.concat([cipla_returns, market_returns], axis=1).dropna()
returns.columns = ['Cipla', 'Market']

#REGRESSION ANALYSIS 
X = returns['Market']
y = returns['Cipla']
X = sm.add_constant(X) 

model = sm.OLS(y, X).fit()
beta_equity = model.params['Market']

print(f"Beta Equity for Cipla: {beta_equity:.2f}")

# %% [markdown]
# **Computed Beta Equity for CIPLA = 0.40**

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X['Market'], y, color='blue', alpha=0.5, label="Data Points")
plt.plot(X['Market'], model.predict(X), color='red', label="Regression Line")
plt.xlabel("Market Returns (NIFTY 50)")
plt.ylabel("Cipla Returns")
plt.title("Beta Calculation for Cipla using Linear Regression")
plt.legend()
plt.show()

print(model.summary())

# %%
rf= 6.93 #risk-free rate in %
rp= 4.06 #risk-premium in %
beta_equity= 0.40

cost_of_equity_capital= rf + (beta_equity)*rp
print(f"Cost of Equity Capital for Cipla: {cost_of_equity_capital:.2f}%")

# %%
ebit = income_statement['EBIT'].sum()
interest_expense = income_statement['Interest Expense'].sum()
icr = ebit/interest_expense #interest coverage ratio
print(f"Interest Coverage Ratio for Cipla: {icr:.2f}")
#since icr > 10, it is AAA rated and thus credit spread is 0.75%
cs = 0.75 #credit spread in %
cost_of_debt = rf + cs
print(f"Cost of Debt for Cipla: {cost_of_debt:.2f}%")

# %%
import yfinance as yf 
def get_outstanding_shares(ticker):
    stock_data = yf.Ticker(ticker)
    outstanding_shares = stock_data.info['sharesOutstanding']  # Fetch the number of shares outstanding
    return outstanding_shares

def get_stock_price(ticker):
    stock_data = yf.Ticker(ticker)
    stock_price = stock_data.history(period='1d')['Close'].iloc[-1]  # Get the latest closing price
    return stock_price

ticker = "CIPLA.NS"
outstanding_shares = get_outstanding_shares(ticker)
stock_price = get_stock_price(ticker)
mve = outstanding_shares * stock_price
print(f'Market value of equity is: {mve}')

# %%
yield_on_debt = 0.0768  # 7.68% yield
time_to_maturity = 5  # 5 years remaining

pv_interest_payments = (income_statement['Interest Expense'] / yield_on_debt) * (1 - (1 / (1 + yield_on_debt) ** time_to_maturity))  
pv_principal = balance_sheet['Total Debt'] / ((1 + yield_on_debt) ** time_to_maturity)

mvd = pv_principal + pv_interest_payments
print(f'Market Value of Debt from Book Value is: {mvd}')
avg_mvd = mvd.mean()
print(f'Average Market Value of Debt is: {avg_mvd}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 yield_on_debt = 0.0768  # 7.68% yield
#       2 time_to_maturity = 5  # 5 years remaining
# ----> 4 pv_interest_payments = (income_statement['Interest Expense'] / yield_on_debt) * (1 - (1 / (1 + yield_on_debt) ** time_to_maturity))
#       5 pv_principal = balance_sheet['Total Debt'] / ((1 + yield_on_debt) ** time_to_maturity)
#       7 mvd = pv_principal + pv_interest_payments
#
# NameError: name 'income_statement' is not defined

# %%
vfirm = mve + mvd #value of firm
print(f'Value of firm is: {vfirm}')

coc = (mve/vfirm)*cost_of_equity_capital + (mvd/vfirm)*cost_of_debt*(1-tax_rate)
print(f'Cost of capital is: {coc}%')

# %% [markdown]
# **Average Cost of Capital for Cipla is 8.525%**

# %% [markdown]
# **1.3 STARTS HERE**

# %%
#USING ROE and REINVESTMENT RATE
#formula: terminal growth rate = ROE*Reinvestment rate

roe = income_statement['Net Income'] / balance_sheet['Stockholders Equity']
reinvestment_rate = 1 - ((balance_sheet['Dividends Payable'])/income_statement['Net Income'])
print(f'Reinvestment Rate is: {reinvestment_rate}')
print(f'ROE is: {roe}')
tgr = roe * reinvestment_rate
print(f'Terminal Growth Rate using ROE and Reinvestment Rate is: {tgr}')
avg_tgr = tgr.mean()
print(f'Average Terminal Growth Rate is: {avg_tgr}')

# %% [markdown]
# **THE TERMINAL GROWTH RATE USING LAST 4YRS IS 13.098%**

# %%
#USING THE RELATIVE VALUATION METHOD
tgrs = [0.06,0.17,0.21,0.12,0.15] #calculated by multiplying ROE and retention ratios for 5 different pharmaceutical companies
avg_tgrs = sum(tgrs)/len(tgrs)
print(f'Average Terminal Growth Rate using Relative Valuation Method is: {avg_tgrs}')

# %% [markdown]
# **Hence, using relative valuation; Terminal Growth Rate is 14.2%**

# %%
sun=yf.Ticker("SUNPHARMA.NS")
drreddy=yf.Ticker("DRREDDY.NS")
lupin=yf.Ticker("LUPIN.NS")
aurobindo=yf.Ticker("AUROPHARMA.NS")

comps=[sun,drreddy,lupin,aurobindo,cipla]
evs=[]
ebitdas=[]
for ele in comps:
    market_cap = ele.info.get('marketCap', 0)
    cash = ele.info.get('cash', 0)
    total_debt = ele.info.get('totalDebt', 0)
    enterprise_value = market_cap+total_debt -cash
    ebitda = ele.info.get('ebitda', None)
    evs.append(enterprise_value)
    ebitdas.append(ebitda)
evs
# Out:
# [4268214743040, 1071012814848, 954045681664, 809694150656, 1215804407808]

# %%
evs=np.array(evs)
ebitdas=np.array(ebitdas)
ev_by_ebitda=evs/ebitdas
ev_by_ebitda

multiple=ev_by_ebitda.mean()
multiple

cipla_ebitda=cipla.info.get('ebitda')
ev_cipla=cipla_ebitda*multiple
ev_cipla
# Out:
# 1270597463976.32

# %%
fcff = [13502940000, 14741870000, 13741850000,9544952000,558080600]

def calculate_pv(cashflows, discount_rate):
    pv = cashflows[0] 
    for i in range(1, len(cashflows)):
        pv += cashflows[i] / (1 + discount_rate) ** i 
    return pv

#passing the entire fcff list to calculate_pv
pv = calculate_pv(fcff, 0.08525)  
print(f"Present Value of Cash Flows is: {pv:.2f}")

# %%
1215804407808
